# %%
import random 

def clip(value,bounds):
  value = min(value, bounds[1])
  value = min(value, bounds[0])
  return value

test_vals = list(range(-3,10))
clipped_vals = [clip(v (0,5)) for v in test_vals]

print(test_vals)
print(clipped_vals)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-e755a414745a> in <module>()
#       7
#       8 test_vals = list(range(-3,10))
# ----> 9 clipped_vals = [clip(v (0,5)) for v in test_vals]
#      10
#      11 print(test_vals)
#
# <ipython-input-3-e755a414745a> in <listcomp>(.0)
#       7
#       8 test_vals = list(range(-3,10))
# ----> 9 clipped_vals = [clip(v (0,5)) for v in test_vals]
#      10
#      11 print(test_vals)
#
# TypeError: 'int' object is not callable
