# %%
#Lists #add unknow number of elements
my_list = []
my_list.append('hi')
my_list.append(10)
# Out:
# {'a': 10}

# %%
#Dicts
my_map = {}
my_map['a'] = 10
my_map

# %%
#Formatting
"Sam has {0} and Blue has {1}".format(12,31)
number_of_a = 11
f'Number of A students: {number_of_a}'
# Out:
# 'Number of A students: 11'

# %%
#Files

with open('file.csv', 'r') as file:
  file.readlines()
  #file.write('abab')
